# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('UNHDD.csv', encoding='cp1252')
df
# Out:
#                       Country Human Development Index (HDI)   HDI Group  \
# 0                     country                            hdi  hdi_group
# 1                      Norway                          0.957  Very high
# 2                     Ireland                          0.955  Very high
# 3                 Switzerland                          0.955  Very high
# 4      Hong Kong, China (SAR)                          0.949  Very high
# ..                        ...                            ...        ...
# 185                   Burundi                          0.433        Low
# 186               South Sudan                          0.433        Low
# 187                      Chad                          0.398        Low
# 188  Central African Republic                          0.397        Low
# 189                     Niger                          0.394        Low
#
#      HDI rank Life expectancy at birth (years)  \
# 0    hdi_rank                             life
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 70 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   Country                                                                                    190 non-null    str
#  1   Human Development Index (HDI)                                                              190 non-null    str
#  2   HDI Group                                                                                  190 non-null    str
#  3   HDI rank                                                                                   190 non-null    str
#  4   Life expectancy at birth (years)                                                           190 non-null    str
# ...
